# %%
# !pip install pyvis

# %%
import requests
import matplotlib.pyplot as plt
import networkx as nx
from pyvis.network import Network

# %%
headers = {
    'Authorization': 'Bearer BQDzA03YAmDZha33J4k0dXNHBWVKE4XsV-is9iHYArCIZ3r5BS78AG-LRFaKaQrGwULEG_yZJHel33XfwYp3sfQDqNtvyA_VlPtgRO4zJgxTR5UY-4s0B0vaGo5c5bbxHyQpR6b44oiJlqtfO9a4bZE7s4qmrgCvx7ETNCQ4ExPQr9qxaT0Zp5MdTDgCRxvwwu2QzHgYvvrC5UdzZcqMehSBQQ'}

playlists = set()

# %%
# !mkdir playlists

# %%
for m in range(0, 100):
    r = requests.get('https://api.spotify.com/v1/search?q=c*&type=playlist&limit=50&offset=' + str(m * 50),
                     headers=headers)
    #print(r.text)
    print(str(m) + "/100")

    try:
        data = r.json()["playlists"]["items"]

        for playlist in data:
            playlists.add(playlist["id"])

            with open('playlists/' + playlist["id"] + '.txt', 'w') as play:
                k = requests.get('https://api.spotify.com/v1/playlists/' + playlist["id"], headers=headers)

                try:
                    data = k.json()["tracks"]["items"]

                    for track in data:
                        try:
                            play.write(
                                track["track"]["id"] + ';' + track["track"]["name"] + ';' +
                                track['track']["artists"][0]["name"] + "\n")
                        except TypeError:
                            print("Skipped song")

                except KeyError:
                    print("Skipped playlist")


    except KeyError:
        print("Skipped playlist")

print("Saved")
# Out:
# 0/100
# Skipped song
# Skipped song
# 1/100
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# 2/100
# 3/100
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# 4/100
# Skipped song
# Skipped song
# 5/100
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# 6/100
# 7/100
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# 8/100
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# Skipped song
# ...

# %%
from os import walk
import networkx as nx
from tqdm import tqdm

# %%
f = []
for (dirpath, dirnames, filenames) in walk('playlists'):
    f.extend(filenames)
    break

print(f)
# Out:
# ['1ijlK4VyCVKcl4aAPLK3pI.txt', '6PrUPPajcmqjmU9AXOsua8.txt', '4fV4LQwjUua5t7pTYBChEi.txt', '0YvZGcwbJQoIvFlOURm9jN.txt', '3ZZBSpcUJ4Gi2uzHjDDpC3.txt', '0eWcjsCVYWcQbi5RieabTI.txt', '5sJzKS028dDi5aCT33Nncs.txt', '340he7yLcAk7XgVQY5Q4YB.txt', '0PjqyWK7uBs2sANSPFDxU1.txt', '2lRR53ckbqQqn1PEPin7sO.txt', '6hruzzKq9PpGZ4OJZebgdx.txt', '6KPQYX8ZtjFetmZSNRZVe1.txt', '38DK4KsJD7dvXhqcIX8hLu.txt', '48MKoayOWxkwrkuXXzhlQj.txt', '7LI3zw8HLkjKo5YpvA26KG.txt', '37i9dQZF1DZ06evO1FfDG2.txt', '6HMYWB8XIO9KGCPgBUMSJw.txt', '6SGRRFbkOROLcFgYwQu3Ik.txt', '0GIwcXe0myy2JBP6xG7waB.txt', '1Mr29ck0LbvduuCPzQoavA.txt', '51qeXDTiDMr9ZYHk61kLxl.txt', '5mzNXi6DDFzO5HYhT9u5rN.txt', '0BvDwObK5Cax6TKpktnMda.txt', '4PvgBKWT32nBn3tM0CjsgR.txt', '45pSaxW1uhSO8SPpTZ05pj.txt', '7h67NeS0CR0gE7k07H2w3c.txt', '7gBfWRdXt1EAi21sj2k0k3.txt', '7cnpWoxyYpTfdi6MdLZRCZ.txt', '0wIF4cDP77c1JacRHi9Y3r.txt', '5A4KncYhd95iKPaIYnjl5B.txt', '4lv0hnEnCAHD8bzPsEFswc.txt', '5yvYmc6Q0u8tv1y40bqXey.txt', '37i9dQZF1DZ06evO0E4eyI.txt', '0HULAv
# ...

# %%
G = nx.Graph()
max = 0
i = 0

# %%
for file in tqdm(f):
    playlist = file[:-4]
    with open('playlists/' + file, 'r') as current:
        content = current.readlines()

    for q in range(0, len(content)):
        for p in range(q, len(content)):
            track1 = content[q][:-1].split(";")
            track2 = content[p][:-1].split(";")

            if track1[0] != track2[0] and track1[0] != 'None' and track2[0] != 'None':
                if G.has_edge(track1[0], track2[0]):
                    if G[track1[0]][track2[0]]['weight'] > max:
                        max = G[track1[0]][track2[0]]['weight']
                    # print('Found high weight for edge (' + track1[0] + ", " + track2[0] + "): " + str(
                    #    G[track1[0]][track2[0]]['weight']))
                    G[track1[0]][track2[0]]['weight'] += 1

                else:
                    G.add_edge(track1[0], track2[0], weight=1)
                    G.nodes[track1[0]]['name'] = track1[1]
                    G.nodes[track1[0]]['artist'] = track1[2]
                    G.nodes[track2[0]]['name'] = track2[1]
                    G.nodes[track2[0]]['artist'] = track2[2]

    # print('Added ' + str(i) + '/' + str(len(f)))
    i = i + 1
    #if i > 300:
    #    break

print('Nodes: ' + str(len(G.nodes)))
print('Edges: ' + str(len(G.edges)))
# Out:
# 100%|██████████| 2844/2844 [00:47<00:00, 59.38it/s]
# Nodes: 139838
# Edges: 7470213

# %%
#Cleaning edges with little correlation to reduce graph size
for u, v, w in list(G.edges(data=True)):
    if w['weight'] < 4:
        G.remove_edge(u, v)

G.remove_nodes_from(list(nx.isolates(G)))

print('Nodes: ' + str(len(G.nodes)))
print('Edges: ' + str(len(G.edges)))

pos = nx.spring_layout(G, dim=10)
#nx.draw(G,pos=nx.spring_layout(G))
# Out:
# Nodes: 4482
# Edges: 31473

# %%
print(pos)
# Out:
# {'1BsW5UyD5bY49kL4KK31cG': array([-0.03506505, -0.00616155, -0.07390837,  0.01581553, -0.03102131,
#         0.01583802, -0.00254656,  0.105125  , -0.07382227,  0.03010166]), '0xKK1v4BX5uPqhDK3p2t6r': array([-0.03496775, -0.006158  , -0.07380457,  0.01579457, -0.0310056 ,
#         0.01601368, -0.00254965,  0.10488982, -0.07369239,  0.03017147]), '7vSIrnCBgDdWbQ23BbRaVh': array([-0.03496778, -0.00615798, -0.07380457,  0.01579457, -0.03100557,
#         0.01601362, -0.00254966,  0.10488985, -0.07369239,  0.03017144]), '3LheTucFlu51ozTSTCB563': array([-0.03496797, -0.00615789, -0.07380462,  0.01579451, -0.03100539,
#         0.01601315, -0.00254973,  0.10489   , -0.07369239,  0.03017124]), '27RbPqiHDSA0MT1AFBLnDp': array([-0.03506555, -0.00616152, -0.07390876,  0.01581556, -0.03102125,
#         0.01583696, -0.00254658,  0.10512591, -0.07382272,  0.03010121]), '2W3oAjJp2lAMo57CdoM4NJ': array([-0.03466577, -0.00328588, -0.06299612,  0.01036823, -0.02295633,
# ...

# %%
x = []
for element in pos:
  x.append(pos[element])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=10)

principalComponents = pca.fit_transform(x)

# %%
print(principalComponents)
# Out:
# [[-0.03301066 -0.008867    0.1178379  ... -0.01710755  0.04943779
#   -0.03928054]
#  [-0.03288083 -0.00879718  0.11763604 ... -0.01706451  0.04955578
#   -0.03914373]
#  [-0.03288086 -0.0087972   0.11763605 ... -0.01706454  0.04955572
#   -0.03914375]
#  ...
#  [ 0.01741124 -0.06081527  0.08190943 ... -0.10701304  0.08288493
#   -0.05700138]
#  [ 0.01753146 -0.06071151  0.08191195 ... -0.10692239  0.08282717
#   -0.05706675]
#  [ 0.13871552 -0.10776548 -0.07216186 ... -0.0737953   0.04004469
#    0.0270263 ]]
